# %% [markdown]
# # Review dataset

# %% [markdown]
# Library

# %%
import cv2
import os
from google.colab.patches import cv2_imshow

# %% [markdown]
# Functions

# %%
def f_readfiles(main_root,fldr_img,fldr_gt):
  folder_img = main_root + fldr_img; print(folder_img)
  folder_gt = main_root + fldr_gt; print(folder_gt)
  
  images = []
  for filename in os.listdir(folder_img):
    img = cv2.imread(os.path.join(folder_img,filename))
    gt = cv2.imread(os.path.join(folder_gt,filename),cv2.IMREAD_UNCHANGED)

    cv2_imshow(img)
    cv2_imshow(gt)
    
    if img is not None:
      images.append(img)
  return images

# %% [markdown]
# Test

# %%
main_root = '/content/drive/MyDrive/Proyecto_CalculosRenales/Imagenes/Dataset/Jonathan Elbeze/Labeled/'

# %% [markdown]
# AU - SEC

# %%
fldr_img = 'Acide urique/section/'
fldr_gt = 'Acide urique/PixelLabelData/'
images = f_readfiles(main_root,fldr_img,fldr_gt)
# Out:
# /content/drive/MyDrive/Proyecto_CalculosRenales/Imagenes/Dataset/Jonathan Elbeze/Labeled/Acide urique/section/
# /content/drive/MyDrive/Proyecto_CalculosRenales/Imagenes/Dataset/Jonathan Elbeze/Labeled/Acide urique/PixelLabelData/
# <PIL.Image.Image image mode=RGB size=768x576 at 0x7F39ED7E2710>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-4227e947ec53> in <module>()
#       1 fldr_img = 'Acide urique/section/'
#       2 fldr_gt = 'Acide urique/PixelLabelData/'
# ----> 3 images = f_readfiles(main_root,fldr_img,fldr_gt)
#
# <ipython-input-36-c63663baf381> in f_readfiles(main_root, fldr_img, fldr_gt)
#       9
#      10     cv2_imshow(img)
# ---> 11     cv2_imshow(gt)
#      12
#      13     if img is not None:
#
# /usr/local/lib/python3.7/dist-packages/google/colab/patches/__init__.py in cv2_imshow(a)
#      20       image.
#      21   """
# ...
