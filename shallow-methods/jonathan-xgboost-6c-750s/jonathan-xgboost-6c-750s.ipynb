# %% [markdown]
# # jonathan-xgboost-6c-750s.ipynb
#
# Details:
#
# *   Dataset: Jonathan El-Beze dataset (6 classes)
# *   Model: xgboost with hyper-parameters

# %% [markdown]
# # XGboost model

# %% [markdown]
# # Hyper-parameter tunning

# %% [markdown]
# # XGboost model with hyper-parameter tunning
